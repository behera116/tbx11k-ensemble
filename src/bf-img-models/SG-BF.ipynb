# %%
import numpy as np
import pandas as pd
from tensorflow.keras.applications import EfficientNetB0
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import models
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
import cv2
import os
from skimage import exposure
import matplotlib
matplotlib.rcParams.update({'font.size': 16})
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.math import confusion_matrix
from sklearn.metrics import accuracy_score
from seaborn import heatmap
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from ast import literal_eval
from matplotlib.patches import Rectangle

# %%
LEARNING_RATE = 1e-3
TARGET_SIZE = (224,224)
INPUT_SHAPE = (224,224,3)
EPOCHS = 60

CLASS_MODE = 'categorical'
LOSS_METRIC = 'categorical_crossentropy'

MODEL_SAVED_FILE = './weights/sg_bf5.hdf5'
TRAIN_IMAGE_FOLDER = '/home/TBX11K/BF/train'
VALIDATION_IMAGE_FOLDER = '/home/TBX11K/BF/val'

NUM_MODELS = 3
SEED = 42
IMAGE_SHAPE = (224,224)
BATCH_SIZE = 16

# %% [markdown]
# ### Load Base Classifiers

# %%
def changeLayerName(model,model_prefix):
    for layer in model.layers:
        layer._name = model_prefix+'_'+layer.name
        layer.trainable = False
    return model

# %%
TRAINING_DIR = '/home/Training'
effnet_path = os.path.join(TRAINING_DIR,'EfficientNet/weights','efficientnet_bf.hdf5')
chexnet_path = os.path.join(TRAINING_DIR,'ChexNet/weights','chexnet_bf.hdf5')
squeezenet_path = os.path.join(TRAINING_DIR,'SqueezeNet/weights','squeezenet_bf.hdf5')

effnet_model = tf.keras.models.load_model(effnet_path)
effnet_model._name="EfficientNet"
effnet_model = changeLayerName(effnet_model,'effnet')

chexnet_model = tf.keras.models.load_model(chexnet_path)
chexnet_model._name="ChexNet"
chexnet_model = changeLayerName(chexnet_model,'chexnet')

squeezenet_model = tf.keras.models.load_model(squeezenet_path)
squeezenet_model._name="SqueezeNet"
squeezenet_model = changeLayerName(squeezenet_model,'snet')
# Out:
# 2022-08-17 09:15:49.311705: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-17 09:15:49.311764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13032 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1b:00.0, compute capability: 7.5

# %% [markdown]
# #### Extract Features from base classifiers

# %%
# SqueezeNet Features. Average pooling to make it (7X7X1000)
squeezenet_features = squeezenet_model.layers[-4].output
squeezenet_features = tf.keras.layers.AveragePooling2D(pool_size=(2, 2),padding="same")(squeezenet_features)

eff_features = effnet_model.layers[-4].output
chexnet_features = chexnet_model.layers[-4].output

concatenated_features = tf.keras.layers.Concatenate(name='DeepConcatenatedFeatures')([eff_features, chexnet_features,squeezenet_features])

# %% [markdown]
# #### Create Model from Concatenated Features

# %%
x = tf.keras.layers.GlobalAveragePooling2D()(concatenated_features)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(32, activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(64, activation="relu")(x)
y = tf.keras.layers.Dense(3, activation="softmax", kernel_initializer="he_normal")(x)
stacked_model = tf.keras.Model(inputs=[effnet_model.input,chexnet_model.input,squeezenet_model.input], outputs=y,name='StackedGeneralization')
stacked_model.summary()
# Out:
# Model: "StackedGeneralization"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  chexnet_input_1 (InputLayer)   [(None, 224, 224, 3  0           []
#                                 )]
#
#  chexnet_zero_padding2d (ZeroPa  (None, 230, 230, 3)  0          ['chexnet_input_1[0][0]']
#  dding2D)
#
#  chexnet_conv1/conv (Conv2D)    (None, 112, 112, 64  9408        ['chexnet_zero_padding2d[0][0]']
#                                 )
#
#  chexnet_conv1/bn (BatchNormali  (None, 112, 112, 64  256        ['chexnet_conv1/conv[0][0]']
#  zation)                        )
#
#  chexnet_conv1/relu (Activation  (None, 112, 112, 64  0          ['chexnet_conv1/bn[0][0]']
#  )                              )
#
#  chexnet_zero_padding2d_1 (Zero  (None, 114, 114, 64  0          ['chexnet_conv1/relu[0][0]']
#  Padding2D)                     )
#
#  chexnet_pool1 (MaxPooling2D)   (None, 56, 56, 64)   0           ['chexnet_zero_padding2d_1[0][0]'
#                                                                  ]
#
#  chexnet_conv2_block1_0_bn (Bat  (None, 56, 56, 64)  256         ['chexnet_pool1[0][0]']
#  chNormalization)
#
#  chexnet_conv2_block1_0_relu (A  (None, 56, 56, 64)  0           ['chexnet_conv2_block1_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block1_1_conv (C  (None, 56, 56, 128)  8192       ['chexnet_conv2_block1_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block1_1_bn (Bat  (None, 56, 56, 128)  512        ['chexnet_conv2_block1_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block1_1_relu (A  (None, 56, 56, 128)  0          ['chexnet_conv2_block1_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block1_2_conv (C  (None, 56, 56, 32)  36864       ['chexnet_conv2_block1_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block1_concat (C  (None, 56, 56, 96)  0           ['chexnet_pool1[0][0]',
#  oncatenate)                                                      'chexnet_conv2_block1_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv2_block2_0_bn (Bat  (None, 56, 56, 96)  384         ['chexnet_conv2_block1_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block2_0_relu (A  (None, 56, 56, 96)  0           ['chexnet_conv2_block2_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block2_1_conv (C  (None, 56, 56, 128)  12288      ['chexnet_conv2_block2_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block2_1_bn (Bat  (None, 56, 56, 128)  512        ['chexnet_conv2_block2_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block2_1_relu (A  (None, 56, 56, 128)  0          ['chexnet_conv2_block2_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block2_2_conv (C  (None, 56, 56, 32)  36864       ['chexnet_conv2_block2_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block2_concat (C  (None, 56, 56, 128)  0          ['chexnet_conv2_block1_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv2_block2_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv2_block3_0_bn (Bat  (None, 56, 56, 128)  512        ['chexnet_conv2_block2_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block3_0_relu (A  (None, 56, 56, 128)  0          ['chexnet_conv2_block3_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block3_1_conv (C  (None, 56, 56, 128)  16384      ['chexnet_conv2_block3_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block3_1_bn (Bat  (None, 56, 56, 128)  512        ['chexnet_conv2_block3_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block3_1_relu (A  (None, 56, 56, 128)  0          ['chexnet_conv2_block3_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block3_2_conv (C  (None, 56, 56, 32)  36864       ['chexnet_conv2_block3_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block3_concat (C  (None, 56, 56, 160)  0          ['chexnet_conv2_block2_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv2_block3_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv2_block4_0_bn (Bat  (None, 56, 56, 160)  640        ['chexnet_conv2_block3_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block4_0_relu (A  (None, 56, 56, 160)  0          ['chexnet_conv2_block4_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block4_1_conv (C  (None, 56, 56, 128)  20480      ['chexnet_conv2_block4_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block4_1_bn (Bat  (None, 56, 56, 128)  512        ['chexnet_conv2_block4_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block4_1_relu (A  (None, 56, 56, 128)  0          ['chexnet_conv2_block4_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block4_2_conv (C  (None, 56, 56, 32)  36864       ['chexnet_conv2_block4_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block4_concat (C  (None, 56, 56, 192)  0          ['chexnet_conv2_block3_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv2_block4_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv2_block5_0_bn (Bat  (None, 56, 56, 192)  768        ['chexnet_conv2_block4_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block5_0_relu (A  (None, 56, 56, 192)  0          ['chexnet_conv2_block5_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block5_1_conv (C  (None, 56, 56, 128)  24576      ['chexnet_conv2_block5_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block5_1_bn (Bat  (None, 56, 56, 128)  512        ['chexnet_conv2_block5_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block5_1_relu (A  (None, 56, 56, 128)  0          ['chexnet_conv2_block5_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block5_2_conv (C  (None, 56, 56, 32)  36864       ['chexnet_conv2_block5_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block5_concat (C  (None, 56, 56, 224)  0          ['chexnet_conv2_block4_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv2_block5_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv2_block6_0_bn (Bat  (None, 56, 56, 224)  896        ['chexnet_conv2_block5_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block6_0_relu (A  (None, 56, 56, 224)  0          ['chexnet_conv2_block6_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block6_1_conv (C  (None, 56, 56, 128)  28672      ['chexnet_conv2_block6_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block6_1_bn (Bat  (None, 56, 56, 128)  512        ['chexnet_conv2_block6_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv2_block6_1_relu (A  (None, 56, 56, 128)  0          ['chexnet_conv2_block6_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv2_block6_2_conv (C  (None, 56, 56, 32)  36864       ['chexnet_conv2_block6_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv2_block6_concat (C  (None, 56, 56, 256)  0          ['chexnet_conv2_block5_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv2_block6_2_conv[0][
#                                                                  0]']
#
#  chexnet_pool2_bn (BatchNormali  (None, 56, 56, 256)  1024       ['chexnet_conv2_block6_concat[0][
#  zation)                                                         0]']
#
#  chexnet_pool2_relu (Activation  (None, 56, 56, 256)  0          ['chexnet_pool2_bn[0][0]']
#  )
#
#  chexnet_pool2_conv (Conv2D)    (None, 56, 56, 128)  32768       ['chexnet_pool2_relu[0][0]']
#
#  chexnet_pool2_pool (AveragePoo  (None, 28, 28, 128)  0          ['chexnet_pool2_conv[0][0]']
#  ling2D)
#
#  chexnet_conv3_block1_0_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_pool2_pool[0][0]']
#  chNormalization)
#
#  chexnet_conv3_block1_0_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block1_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block1_1_conv (C  (None, 28, 28, 128)  16384      ['chexnet_conv3_block1_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block1_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block1_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block1_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block1_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block1_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block1_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block1_concat (C  (None, 28, 28, 160)  0          ['chexnet_pool2_pool[0][0]',
#  oncatenate)                                                      'chexnet_conv3_block1_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block2_0_bn (Bat  (None, 28, 28, 160)  640        ['chexnet_conv3_block1_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block2_0_relu (A  (None, 28, 28, 160)  0          ['chexnet_conv3_block2_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block2_1_conv (C  (None, 28, 28, 128)  20480      ['chexnet_conv3_block2_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block2_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block2_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block2_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block2_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block2_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block2_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block2_concat (C  (None, 28, 28, 192)  0          ['chexnet_conv3_block1_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv3_block2_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block3_0_bn (Bat  (None, 28, 28, 192)  768        ['chexnet_conv3_block2_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block3_0_relu (A  (None, 28, 28, 192)  0          ['chexnet_conv3_block3_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block3_1_conv (C  (None, 28, 28, 128)  24576      ['chexnet_conv3_block3_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block3_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block3_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block3_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block3_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block3_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block3_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block3_concat (C  (None, 28, 28, 224)  0          ['chexnet_conv3_block2_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv3_block3_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block4_0_bn (Bat  (None, 28, 28, 224)  896        ['chexnet_conv3_block3_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block4_0_relu (A  (None, 28, 28, 224)  0          ['chexnet_conv3_block4_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block4_1_conv (C  (None, 28, 28, 128)  28672      ['chexnet_conv3_block4_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block4_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block4_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block4_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block4_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block4_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block4_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block4_concat (C  (None, 28, 28, 256)  0          ['chexnet_conv3_block3_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv3_block4_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block5_0_bn (Bat  (None, 28, 28, 256)  1024       ['chexnet_conv3_block4_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block5_0_relu (A  (None, 28, 28, 256)  0          ['chexnet_conv3_block5_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block5_1_conv (C  (None, 28, 28, 128)  32768      ['chexnet_conv3_block5_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block5_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block5_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block5_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block5_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block5_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block5_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block5_concat (C  (None, 28, 28, 288)  0          ['chexnet_conv3_block4_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv3_block5_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block6_0_bn (Bat  (None, 28, 28, 288)  1152       ['chexnet_conv3_block5_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block6_0_relu (A  (None, 28, 28, 288)  0          ['chexnet_conv3_block6_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block6_1_conv (C  (None, 28, 28, 128)  36864      ['chexnet_conv3_block6_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block6_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block6_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block6_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block6_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block6_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block6_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block6_concat (C  (None, 28, 28, 320)  0          ['chexnet_conv3_block5_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv3_block6_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block7_0_bn (Bat  (None, 28, 28, 320)  1280       ['chexnet_conv3_block6_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block7_0_relu (A  (None, 28, 28, 320)  0          ['chexnet_conv3_block7_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block7_1_conv (C  (None, 28, 28, 128)  40960      ['chexnet_conv3_block7_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block7_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block7_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block7_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block7_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block7_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block7_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block7_concat (C  (None, 28, 28, 352)  0          ['chexnet_conv3_block6_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv3_block7_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block8_0_bn (Bat  (None, 28, 28, 352)  1408       ['chexnet_conv3_block7_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block8_0_relu (A  (None, 28, 28, 352)  0          ['chexnet_conv3_block8_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block8_1_conv (C  (None, 28, 28, 128)  45056      ['chexnet_conv3_block8_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block8_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block8_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block8_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block8_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block8_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block8_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block8_concat (C  (None, 28, 28, 384)  0          ['chexnet_conv3_block7_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv3_block8_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block9_0_bn (Bat  (None, 28, 28, 384)  1536       ['chexnet_conv3_block8_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block9_0_relu (A  (None, 28, 28, 384)  0          ['chexnet_conv3_block9_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block9_1_conv (C  (None, 28, 28, 128)  49152      ['chexnet_conv3_block9_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block9_1_bn (Bat  (None, 28, 28, 128)  512        ['chexnet_conv3_block9_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv3_block9_1_relu (A  (None, 28, 28, 128)  0          ['chexnet_conv3_block9_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv3_block9_2_conv (C  (None, 28, 28, 32)  36864       ['chexnet_conv3_block9_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv3_block9_concat (C  (None, 28, 28, 416)  0          ['chexnet_conv3_block8_concat[0][
#  oncatenate)                                                     0]',
#                                                                   'chexnet_conv3_block9_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv3_block10_0_bn (Ba  (None, 28, 28, 416)  1664       ['chexnet_conv3_block9_concat[0][
#  tchNormalization)                                               0]']
#
#  chexnet_conv3_block10_0_relu (  (None, 28, 28, 416)  0          ['chexnet_conv3_block10_0_bn[0][0
#  Activation)                                                     ]']
#
#  chexnet_conv3_block10_1_conv (  (None, 28, 28, 128)  53248      ['chexnet_conv3_block10_0_relu[0]
#  Conv2D)                                                         [0]']
#
#  chexnet_conv3_block10_1_bn (Ba  (None, 28, 28, 128)  512        ['chexnet_conv3_block10_1_conv[0]
#  tchNormalization)                                               [0]']
#
#  chexnet_conv3_block10_1_relu (  (None, 28, 28, 128)  0          ['chexnet_conv3_block10_1_bn[0][0
#  Activation)                                                     ]']
#
#  chexnet_conv3_block10_2_conv (  (None, 28, 28, 32)  36864       ['chexnet_conv3_block10_1_relu[0]
#  Conv2D)                                                         [0]']
#
#  chexnet_conv3_block10_concat (  (None, 28, 28, 448)  0          ['chexnet_conv3_block9_concat[0][
#  Concatenate)                                                    0]',
#                                                                   'chexnet_conv3_block10_2_conv[0]
#                                                                  [0]']
#
#  chexnet_conv3_block11_0_bn (Ba  (None, 28, 28, 448)  1792       ['chexnet_conv3_block10_concat[0]
#  tchNormalization)                                               [0]']
#
#  chexnet_conv3_block11_0_relu (  (None, 28, 28, 448)  0          ['chexnet_conv3_block11_0_bn[0][0
#  Activation)                                                     ]']
#
#  chexnet_conv3_block11_1_conv (  (None, 28, 28, 128)  57344      ['chexnet_conv3_block11_0_relu[0]
#  Conv2D)                                                         [0]']
#
#  chexnet_conv3_block11_1_bn (Ba  (None, 28, 28, 128)  512        ['chexnet_conv3_block11_1_conv[0]
#  tchNormalization)                                               [0]']
#
#  chexnet_conv3_block11_1_relu (  (None, 28, 28, 128)  0          ['chexnet_conv3_block11_1_bn[0][0
#  Activation)                                                     ]']
#
#  chexnet_conv3_block11_2_conv (  (None, 28, 28, 32)  36864       ['chexnet_conv3_block11_1_relu[0]
#  Conv2D)                                                         [0]']
#
#  chexnet_conv3_block11_concat (  (None, 28, 28, 480)  0          ['chexnet_conv3_block10_concat[0]
#  Concatenate)                                                    [0]',
#                                                                   'chexnet_conv3_block11_2_conv[0]
#                                                                  [0]']
#
#  chexnet_conv3_block12_0_bn (Ba  (None, 28, 28, 480)  1920       ['chexnet_conv3_block11_concat[0]
#  tchNormalization)                                               [0]']
#
#  chexnet_conv3_block12_0_relu (  (None, 28, 28, 480)  0          ['chexnet_conv3_block12_0_bn[0][0
#  Activation)                                                     ]']
#
#  chexnet_conv3_block12_1_conv (  (None, 28, 28, 128)  61440      ['chexnet_conv3_block12_0_relu[0]
#  Conv2D)                                                         [0]']
#
#  chexnet_conv3_block12_1_bn (Ba  (None, 28, 28, 128)  512        ['chexnet_conv3_block12_1_conv[0]
#  tchNormalization)                                               [0]']
#
#  chexnet_conv3_block12_1_relu (  (None, 28, 28, 128)  0          ['chexnet_conv3_block12_1_bn[0][0
#  Activation)                                                     ]']
#
#  chexnet_conv3_block12_2_conv (  (None, 28, 28, 32)  36864       ['chexnet_conv3_block12_1_relu[0]
#  Conv2D)                                                         [0]']
#
#  chexnet_conv3_block12_concat (  (None, 28, 28, 512)  0          ['chexnet_conv3_block11_concat[0]
#  Concatenate)                                                    [0]',
#                                                                   'chexnet_conv3_block12_2_conv[0]
#                                                                  [0]']
#
#  chexnet_pool3_bn (BatchNormali  (None, 28, 28, 512)  2048       ['chexnet_conv3_block12_concat[0]
#  zation)                                                         [0]']
#
#  chexnet_pool3_relu (Activation  (None, 28, 28, 512)  0          ['chexnet_pool3_bn[0][0]']
#  )
#
#  chexnet_pool3_conv (Conv2D)    (None, 28, 28, 256)  131072      ['chexnet_pool3_relu[0][0]']
#
#  chexnet_pool3_pool (AveragePoo  (None, 14, 14, 256)  0          ['chexnet_pool3_conv[0][0]']
#  ling2D)
#
#  chexnet_conv4_block1_0_bn (Bat  (None, 14, 14, 256)  1024       ['chexnet_pool3_pool[0][0]']
#  chNormalization)
#
#  chexnet_conv4_block1_0_relu (A  (None, 14, 14, 256)  0          ['chexnet_conv4_block1_0_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv4_block1_1_conv (C  (None, 14, 14, 128)  32768      ['chexnet_conv4_block1_0_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv4_block1_1_bn (Bat  (None, 14, 14, 128)  512        ['chexnet_conv4_block1_1_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv4_block1_1_relu (A  (None, 14, 14, 128)  0          ['chexnet_conv4_block1_1_bn[0][0]
#  ctivation)                                                      ']
#
#  chexnet_conv4_block1_2_conv (C  (None, 14, 14, 32)  36864       ['chexnet_conv4_block1_1_relu[0][
#  onv2D)                                                          0]']
#
#  chexnet_conv4_block1_concat (C  (None, 14, 14, 288)  0          ['chexnet_pool3_pool[0][0]',
#  oncatenate)                                                      'chexnet_conv4_block1_2_conv[0][
#                                                                  0]']
#
#  chexnet_conv4_block2_0_bn (Bat  (None, 14, 14, 288)  1152       ['chexnet_conv4_block1_concat[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv4_block2_0_relu (A  (None, 14, 14, 288)  0          ['chexnet_conv4_block2_0_bn[0][0]
# ...
#
#  snet_fire8/squeeze1x1 (Conv2D)  (None, 13, 13, 64)  24640       ['snet_fire7/concat[0][0]']
#
#  effnet_block7a_dwconv (Depthwi  (None, 7, 7, 1152)  10368       ['effnet_block7a_expand_activatio
#  seConv2D)                                                       n[0][0]']
#
#  chexnet_conv5_block15_1_bn (Ba  (None, 7, 7, 128)   512         ['chexnet_conv5_block15_1_conv[0]
#  tchNormalization)                                               [0]']
#
#  snet_fire8/relu_squeeze1x1 (Ac  (None, 13, 13, 64)  0           ['snet_fire8/squeeze1x1[0][0]']
#  tivation)
#
#  effnet_block7a_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['effnet_block7a_dwconv[0][0]']
#  ization)
#
#  chexnet_conv5_block15_1_relu (  (None, 7, 7, 128)   0           ['chexnet_conv5_block15_1_bn[0][0
#  Activation)                                                     ]']
#
#  snet_fire8/expand1x1 (Conv2D)  (None, 13, 13, 256)  16640       ['snet_fire8/relu_squeeze1x1[0][0
#                                                                  ]']
#
#  snet_fire8/expand3x3 (Conv2D)  (None, 13, 13, 256)  147712      ['snet_fire8/relu_squeeze1x1[0][0
#                                                                  ]']
#
#  effnet_block7a_activation (Act  (None, 7, 7, 1152)  0           ['effnet_block7a_bn[0][0]']
#  ivation)
#
#  chexnet_conv5_block15_2_conv (  (None, 7, 7, 32)    36864       ['chexnet_conv5_block15_1_relu[0]
#  Conv2D)                                                         [0]']
#
#  snet_fire8/relu_expand1x1 (Act  (None, 13, 13, 256)  0          ['snet_fire8/expand1x1[0][0]']
#  ivation)
#
#  snet_fire8/relu_expand3x3 (Act  (None, 13, 13, 256)  0          ['snet_fire8/expand3x3[0][0]']
#  ivation)
#
#  effnet_block7a_se_squeeze (Glo  (None, 1152)        0           ['effnet_block7a_activation[0][0]
#  balAveragePooling2D)                                            ']
#
#  chexnet_conv5_block15_concat (  (None, 7, 7, 992)   0           ['chexnet_conv5_block14_concat[0]
#  Concatenate)                                                    [0]',
#                                                                   'chexnet_conv5_block15_2_conv[0]
#                                                                  [0]']
#
#  snet_fire8/concat (Concatenate  (None, 13, 13, 512)  0          ['snet_fire8/relu_expand1x1[0][0]
#  )                                                               ',
#                                                                   'snet_fire8/relu_expand3x3[0][0]
#                                                                  ']
#
#  effnet_block7a_se_reshape (Res  (None, 1, 1, 1152)  0           ['effnet_block7a_se_squeeze[0][0]
#  hape)                                                           ']
#
#  chexnet_conv5_block16_0_bn (Ba  (None, 7, 7, 992)   3968        ['chexnet_conv5_block15_concat[0]
#  tchNormalization)                                               [0]']
#
#  snet_fire9/squeeze1x1 (Conv2D)  (None, 13, 13, 64)  32832       ['snet_fire8/concat[0][0]']
#
#  effnet_block7a_se_reduce (Conv  (None, 1, 1, 48)    55344       ['effnet_block7a_se_reshape[0][0]
#  2D)                                                             ']
#
#  chexnet_conv5_block16_0_relu (  (None, 7, 7, 992)   0           ['chexnet_conv5_block16_0_bn[0][0
#  Activation)                                                     ]']
#
#  snet_fire9/relu_squeeze1x1 (Ac  (None, 13, 13, 64)  0           ['snet_fire9/squeeze1x1[0][0]']
#  tivation)
#
#  effnet_block7a_se_expand (Conv  (None, 1, 1, 1152)  56448       ['effnet_block7a_se_reduce[0][0]'
#  2D)                                                             ]
#
#  chexnet_conv5_block16_1_conv (  (None, 7, 7, 128)   126976      ['chexnet_conv5_block16_0_relu[0]
#  Conv2D)                                                         [0]']
#
#  snet_fire9/expand1x1 (Conv2D)  (None, 13, 13, 256)  16640       ['snet_fire9/relu_squeeze1x1[0][0
#                                                                  ]']
#
#  snet_fire9/expand3x3 (Conv2D)  (None, 13, 13, 256)  147712      ['snet_fire9/relu_squeeze1x1[0][0
#                                                                  ]']
#
#  effnet_block7a_se_excite (Mult  (None, 7, 7, 1152)  0           ['effnet_block7a_activation[0][0]
#  iply)                                                           ',
#                                                                   'effnet_block7a_se_expand[0][0]'
#                                                                  ]
#
#  chexnet_conv5_block16_1_bn (Ba  (None, 7, 7, 128)   512         ['chexnet_conv5_block16_1_conv[0]
#  tchNormalization)                                               [0]']
#
#  snet_fire9/relu_expand1x1 (Act  (None, 13, 13, 256)  0          ['snet_fire9/expand1x1[0][0]']
#  ivation)
#
#  snet_fire9/relu_expand3x3 (Act  (None, 13, 13, 256)  0          ['snet_fire9/expand3x3[0][0]']
#  ivation)
#
#  effnet_block7a_project_conv (C  (None, 7, 7, 320)   368640      ['effnet_block7a_se_excite[0][0]'
#  onv2D)                                                          ]
#
#  chexnet_conv5_block16_1_relu (  (None, 7, 7, 128)   0           ['chexnet_conv5_block16_1_bn[0][0
#  Activation)                                                     ]']
#
#  snet_fire9/concat (Concatenate  (None, 13, 13, 512)  0          ['snet_fire9/relu_expand1x1[0][0]
#  )                                                               ',
#                                                                   'snet_fire9/relu_expand3x3[0][0]
#                                                                  ']
#
#  effnet_block7a_project_bn (Bat  (None, 7, 7, 320)   1280        ['effnet_block7a_project_conv[0][
#  chNormalization)                                                0]']
#
#  chexnet_conv5_block16_2_conv (  (None, 7, 7, 32)    36864       ['chexnet_conv5_block16_1_relu[0]
#  Conv2D)                                                         [0]']
#
#  snet_drop9 (Dropout)           (None, 13, 13, 512)  0           ['snet_fire9/concat[0][0]']
#
#  effnet_top_conv (Conv2D)       (None, 7, 7, 1280)   409600      ['effnet_block7a_project_bn[0][0]
#                                                                  ']
#
#  chexnet_conv5_block16_concat (  (None, 7, 7, 1024)  0           ['chexnet_conv5_block15_concat[0]
#  Concatenate)                                                    [0]',
#                                                                   'chexnet_conv5_block16_2_conv[0]
#                                                                  [0]']
#
#  snet_conv10 (Conv2D)           (None, 13, 13, 1000  513000      ['snet_drop9[0][0]']
#                                 )
#
#  effnet_top_bn (BatchNormalizat  (None, 7, 7, 1280)  5120        ['effnet_top_conv[0][0]']
#  ion)
#
#  chexnet_bn (BatchNormalization  (None, 7, 7, 1024)  4096        ['chexnet_conv5_block16_concat[0]
#  )                                                               [0]']
#
#  snet_relu_conv10 (Activation)  (None, 13, 13, 1000  0           ['snet_conv10[0][0]']
#                                 )
#
#  effnet_top_activation (Activat  (None, 7, 7, 1280)  0           ['effnet_top_bn[0][0]']
#  ion)
#
#  chexnet_relu (Activation)      (None, 7, 7, 1024)   0           ['chexnet_bn[0][0]']
#
#  average_pooling2d (AveragePool  (None, 7, 7, 1000)  0           ['snet_relu_conv10[0][0]']
#  ing2D)
#
#  DeepConcatenatedFeatures (Conc  (None, 7, 7, 3304)  0           ['effnet_top_activation[0][0]',
#  atenate)                                                         'chexnet_relu[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  global_average_pooling2d (Glob  (None, 3304)        0           ['DeepConcatenatedFeatures[0][0]'
#  alAveragePooling2D)                                             ]
#
#  dropout (Dropout)              (None, 3304)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 32)           105760      ['dropout[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32)          128         ['dense[0][0]']
#  alization)
#
#  dense_1 (Dense)                (None, 64)           2112        ['batch_normalization[0][0]']
#
#  dense_2 (Dense)                (None, 3)            195         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 12,430,766
# Trainable params: 108,131
# Non-trainable params: 12,322,635
# __________________________________________________________________________________________________

# %%
#Plot model
#tf.keras.utils.plot_model(stacked_model, to_file='./voting_ensemble.png', show_shapes=True)

# %% [markdown]
# #### Keras Callbacks

# %%
import datetime as dt
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import LambdaCallback
from keras.callbacks import TensorBoard
from tensorflow.keras import backend as K


tensorboard = TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                            histogram_freq=0,
                            write_graph=False,
                            update_freq='epoch')

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(stacked_model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(stacked_model.optimizer.lr))
    
def train_begin(logs):
    os.system("echo Beginning training")
    

checkpoint = ModelCheckpoint(MODEL_SAVED_FILE,
                             monitor='val_loss',
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             save_weights_only=False,
                             save_freq='epoch')

earlystop = EarlyStopping(monitor='val_loss',
                          min_delta = 1e-4, 
                          patience=30,
                          verbose=1,
                          mode='min',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_loss',
                             factor=np.sqrt(.1),
                             patience=10,
                             verbose=1,
                             mode='min',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)

# %% [markdown]
# #### Image Data Generator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import random
from sklearn.utils import class_weight


#train data generator
train_datagen = ImageDataGenerator(
    horizontal_flip = True,
    zoom_range = 0.2,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rotation_range=20,
    brightness_range = [0.8, 1.2],
    fill_mode='nearest',
)

train_generator = train_datagen.flow_from_directory(
        TRAIN_IMAGE_FOLDER,
        target_size=TARGET_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=True,
        seed=42,
        class_mode= CLASS_MODE)

#validation imagedatagenerator
test_datagen = ImageDataGenerator()
validation_generator = test_datagen.flow_from_directory(
        VALIDATION_IMAGE_FOLDER,
        target_size=TARGET_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=False,
        seed=42,
        class_mode=CLASS_MODE)
from collections import Counter
print('train class indices:',train_generator.class_indices)
counter = Counter(train_generator.classes)

total_train = 0
num_classes = 0
for cls_idx,item in counter.items():
    total_train += item
    num_classes += 1

class_weights = {}
for cls_idx,weight in counter.items():
    cls_weight = total_train/(weight*num_classes)
    class_weights[cls_idx] = cls_weight

print('class weights:',class_weights)
print('samples for train class labels:',counter.items())
print('\n')

print('validation class indices:',validation_generator.class_indices)
counter = Counter(validation_generator.classes)
print('samples for validation class labels:',counter.items())
# Out:
# Found 9130 images belonging to 3 classes.
# Found 2032 images belonging to 3 classes.
# train class indices: {'health': 0, 'sick': 1, 'tb': 2}
# class weights: {0: 0.972310969116081, 1: 1.0144444444444445, 2: 1.0144444444444445}
# samples for train class labels: dict_items([(0, 3130), (1, 3000), (2, 3000)])
#
#
# validation class indices: {'health': 0, 'sick': 1, 'tb': 2}
# samples for validation class labels: dict_items([(0, 923), (1, 800), (2, 309)])

# %% [markdown]
# #### Construct Multi-input Generators

# %%
def train_generator_func(generator):
    while True:
        x,Y = next(generator)
        X = [x,x,x]
        yield X,Y

def val_generator_func(generator):
    while True:
        x,Y = next(generator)
        X = [x,x,x]
        yield (X,Y)

# %% [markdown]
# #### EfficientNet Compilation and Execution

# %%
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
stacked_model.compile(
    optimizer=adam_optimizer,
    loss= LOSS_METRIC,
    metrics=["accuracy",
             tf.keras.metrics.AUC(name='AUC'),
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')],
)

# %%
warnings.filterwarnings("ignore")
epochs = 15
history = stacked_model.fit(train_generator_func(train_generator),
                                steps_per_epoch=len(train_generator), 
                                validation_data=val_generator_func(validation_generator),
                                validation_steps = len(validation_generator),
                                epochs=epochs,
                                verbose = 1,
                                class_weight = class_weights,
                                callbacks=[reducelr, earlystop,checkpoint,lambdacb])
# Out:
# Beginning training
# Learning rate:  1e-04
# Epoch 1/15
# 2022-08-17 09:16:34.959308: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 571/571 [==============================] - ETA: 0s - loss: 0.2514 - accuracy: 0.9229 - AUC: 0.9883 - precision: 0.9512 - recall: 0.8901
# Epoch 00001: val_loss improved from inf to 0.10536, saving model to ./weights/sg_mergedbc.hdf5
# End of epoch 0. Learning rate: 1e-04
# 571/571 [==============================] - 151s 244ms/step - loss: 0.2514 - accuracy: 0.9229 - AUC: 0.9883 - precision: 0.9512 - recall: 0.8901 - val_loss: 0.1054 - val_accuracy: 0.9651 - val_AUC: 0.9966 - val_precision: 0.9659 - val_recall: 0.9606 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 2/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9759 - AUC: 0.9982 - precision: 0.9800 - recall: 0.9704
# Epoch 00002: val_loss improved from 0.10536 to 0.10366, saving model to ./weights/sg_mergedbc.hdf5
# End of epoch 1. Learning rate: 1e-04
# 571/571 [==============================] - 137s 239ms/step - loss: 0.0842 - accuracy: 0.9759 - AUC: 0.9982 - precision: 0.9800 - recall: 0.9704 - val_loss: 0.1037 - val_accuracy: 0.9636 - val_AUC: 0.9968 - val_precision: 0.9664 - val_recall: 0.9621 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 3/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9815 - AUC: 0.9986 - precision: 0.9834 - recall: 0.9783
# Epoch 00003: val_loss improved from 0.10366 to 0.08606, saving model to ./weights/sg_mergedbc.hdf5
# End of epoch 2. Learning rate: 1e-04
# 571/571 [==============================] - 136s 238ms/step - loss: 0.0627 - accuracy: 0.9815 - AUC: 0.9986 - precision: 0.9834 - recall: 0.9783 - val_loss: 0.0861 - val_accuracy: 0.9724 - val_AUC: 0.9970 - val_precision: 0.9739 - val_recall: 0.9719 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 4/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9829 - AUC: 0.9986 - precision: 0.9848 - recall: 0.9808
# Epoch 00004: val_loss did not improve from 0.08606
# End of epoch 3. Learning rate: 1e-04
# 571/571 [==============================] - 135s 236ms/step - loss: 0.0566 - accuracy: 0.9829 - AUC: 0.9986 - precision: 0.9848 - recall: 0.9808 - val_loss: 0.0871 - val_accuracy: 0.9764 - val_AUC: 0.9961 - val_precision: 0.9769 - val_recall: 0.9764 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 5/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9851 - AUC: 0.9989 - precision: 0.9864 - recall: 0.9832
# Epoch 00005: val_loss did not improve from 0.08606
# End of epoch 4. Learning rate: 1e-04
# 571/571 [==============================] - 135s 237ms/step - loss: 0.0473 - accuracy: 0.9851 - AUC: 0.9989 - precision: 0.9864 - recall: 0.9832 - val_loss: 0.0879 - val_accuracy: 0.9739 - val_AUC: 0.9969 - val_precision: 0.9739 - val_recall: 0.9739 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 6/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9869 - AUC: 0.9988 - precision: 0.9880 - recall: 0.9857
# Epoch 00006: val_loss did not improve from 0.08606
# End of epoch 5. Learning rate: 1e-04
# 571/571 [==============================] - 135s 237ms/step - loss: 0.0421 - accuracy: 0.9869 - AUC: 0.9988 - precision: 0.9880 - recall: 0.9857 - val_loss: 0.1029 - val_accuracy: 0.9700 - val_AUC: 0.9956 - val_precision: 0.9700 - val_recall: 0.9695 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 7/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9874 - AUC: 0.9992 - precision: 0.9880 - recall: 0.9866
# Epoch 00007: val_loss did not improve from 0.08606
# End of epoch 6. Learning rate: 1e-04
# 571/571 [==============================] - 135s 236ms/step - loss: 0.0404 - accuracy: 0.9874 - AUC: 0.9992 - precision: 0.9880 - recall: 0.9866 - val_loss: 0.0962 - val_accuracy: 0.9715 - val_AUC: 0.9958 - val_precision: 0.9719 - val_recall: 0.9715 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 8/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9900 - AUC: 0.9993 - precision: 0.9903 - recall: 0.9888
# Epoch 00008: val_loss did not improve from 0.08606
# End of epoch 7. Learning rate: 1e-04
# 571/571 [==============================] - 136s 238ms/step - loss: 0.0342 - accuracy: 0.9900 - AUC: 0.9993 - precision: 0.9903 - recall: 0.9888 - val_loss: 0.0929 - val_accuracy: 0.9744 - val_AUC: 0.9958 - val_precision: 0.9744 - val_recall: 0.9744 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 9/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9907 - AUC: 0.9992 - precision: 0.9911 - recall: 0.9901
# Epoch 00009: val_loss did not improve from 0.08606
# End of epoch 8. Learning rate: 1e-04
# 571/571 [==============================] - 134s 236ms/step - loss: 0.0325 - accuracy: 0.9907 - AUC: 0.9992 - precision: 0.9911 - recall: 0.9901 - val_loss: 0.0930 - val_accuracy: 0.9744 - val_AUC: 0.9957 - val_precision: 0.9744 - val_recall: 0.9739 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 10/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9903 - AUC: 0.9994 - precision: 0.9907 - recall: 0.9894
# Epoch 00010: val_loss did not improve from 0.08606
# End of epoch 9. Learning rate: 1e-04
# 571/571 [==============================] - 135s 237ms/step - loss: 0.0326 - accuracy: 0.9903 - AUC: 0.9994 - precision: 0.9907 - recall: 0.9894 - val_loss: 0.0945 - val_accuracy: 0.9739 - val_AUC: 0.9955 - val_precision: 0.9739 - val_recall: 0.9739 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 11/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9872 - AUC: 0.9987 - precision: 0.9883 - recall: 0.9867
# Epoch 00011: val_loss did not improve from 0.08606
# End of epoch 10. Learning rate: 1e-04
# 571/571 [==============================] - 134s 234ms/step - loss: 0.0403 - accuracy: 0.9872 - AUC: 0.9987 - precision: 0.9883 - recall: 0.9867 - val_loss: 0.0913 - val_accuracy: 0.9749 - val_AUC: 0.9957 - val_precision: 0.9749 - val_recall: 0.9744 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 12/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9899 - AUC: 0.9993 - precision: 0.9909 - recall: 0.9892
# Epoch 00012: val_loss did not improve from 0.08606
# End of epoch 11. Learning rate: 1e-04
# 571/571 [==============================] - 136s 239ms/step - loss: 0.0307 - accuracy: 0.9899 - AUC: 0.9993 - precision: 0.9909 - recall: 0.9892 - val_loss: 0.1076 - val_accuracy: 0.9769 - val_AUC: 0.9931 - val_precision: 0.9769 - val_recall: 0.9764 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 13/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9901 - AUC: 0.9993 - precision: 0.9906 - recall: 0.9897
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
#
# Epoch 00013: val_loss did not improve from 0.08606
# End of epoch 12. Learning rate: 3.1622774e-05
# 571/571 [==============================] - 137s 240ms/step - loss: 0.0336 - accuracy: 0.9901 - AUC: 0.9993 - precision: 0.9906 - recall: 0.9897 - val_loss: 0.1003 - val_accuracy: 0.9764 - val_AUC: 0.9945 - val_precision: 0.9764 - val_recall: 0.9759 - lr: 1.0000e-04
# Learning rate:  3.1622774e-05
# Epoch 14/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9905 - AUC: 0.9991 - precision: 0.9912 - recall: 0.9901
# Epoch 00014: val_loss did not improve from 0.08606
# End of epoch 13. Learning rate: 3.1622774e-05
# 571/571 [==============================] - 137s 241ms/step - loss: 0.0297 - accuracy: 0.9905 - AUC: 0.9991 - precision: 0.9912 - recall: 0.9901 - val_loss: 0.1010 - val_accuracy: 0.9764 - val_AUC: 0.9945 - val_precision: 0.9764 - val_recall: 0.9764 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 15/15
# 571/571 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9917 - AUC: 0.9992 - precision: 0.9920 - recall: 0.9911
# Epoch 00015: val_loss did not improve from 0.08606
# End of epoch 14. Learning rate: 3.1622774e-05
# 571/571 [==============================] - 140s 246ms/step - loss: 0.0298 - accuracy: 0.9917 - AUC: 0.9992 - precision: 0.9920 - recall: 0.9911 - val_loss: 0.0983 - val_accuracy: 0.9759 - val_AUC: 0.9955 - val_precision: 0.9759 - val_recall: 0.9759 - lr: 3.1623e-05

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.title('Training and Validation accuracy')
plt.plot(history.epoch, history.history['accuracy'], label='Training accuracy')
plt.plot(history.epoch, history.history['val_accuracy'], label='Validation accuracy')
plt.legend()

plt.subplot(2, 1, 2)
plt.title('Training and Validation loss')
plt.plot(history.epoch, history.history['loss'], label='Training loss')
plt.plot(history.epoch, history.history['val_loss'], label='Validation loss')
plt.legend()

plt.show()

# %%
import pandas as pd
hist_df = pd.DataFrame(history.history) 
hist_df.index.name='epoch'
hist_df.sort_values(by=['val_loss'],ascending=True)
# Out:
#            loss  accuracy       AUC  precision    recall  val_loss  \
# epoch
# 2      0.062735  0.981490  0.998574   0.983376  0.978313  0.086057
# 3      0.056601  0.982913  0.998641   0.984823  0.980832  0.087147
# 4      0.047305  0.985104  0.998936   0.986375  0.983242  0.087850
# 10     0.040277  0.987185  0.998696   0.988262  0.986747  0.091347
# 7      0.034154  0.990033  0.999266   0.990347  0.988828  0.092900
# 8      0.032515  0.990690  0.999241   0.991119  0.990142  0.092973
# 9      0.032605  0.990252  0.999355   0.990678  0.989376  0.094483
# 6      0.040361  0.987404  0.999179   0.988044  0.986637  0.096204
# 14     0.029837  0.991676  0.999211   0.991997  0.991128  0.098317
# 12     0.033600  0.990142  0.999298   0.990572  0.989704  0.100350
# 13     0.029704  0.990471  0.999123   0.991228  0.990142  0.100972
# 5      0.042109  0.986857  0.998833   0.988033  0.985652  0.102856
# 1      0.084187  0.975904  0.998236   0.979980  0.970427  0.103658
# 0      0.251380  0.922892  0.988344   0.951194  0.890142  0.105363
# 11     0.030734  0.989923  0.999296   0.990893  0.989157  0.107598
#
#        val_accuracy   val_AUC  val_precision  val_recall        lr
# epoch
# 2          0.972441  0.997042       0.973866    0.971949  0.000100
# 3          0.976378  0.996079       0.976859    0.976378  0.000100
# 4          0.973917  0.996891       0.973917    0.973917  0.000100
# 10         0.974902  0.995711       0.974889    0.974409  0.000100
# 7          0.974409  0.995823       0.974409    0.974409  0.000100
# 8          0.974409  0.995656       0.974397    0.973917  0.000100
# 9          0.973917  0.995529       0.973917    0.973917  0.000100
# 6          0.971457  0.995807       0.971935    0.971457  0.000100
# 14         0.975886  0.995544       0.975886    0.975886  0.000032
# 12         0.976378  0.994483       0.976366    0.975886  0.000100
# 13         0.976378  0.994457       0.976378    0.976378  0.000032
# 5          0.969980  0.995634       0.969966    0.969488  0.000100
# 1          0.963583  0.996759       0.966387    0.962106  0.000100
# 0          0.965059  0.996571       0.965858    0.960630  0.000100
# 11         0.976870  0.993107       0.976859    0.976378  0.000100

# %%
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)
stacked_model.compile(
    optimizer=adam_optimizer,
    loss= LOSS_METRIC,
    metrics=["accuracy",
             tf.keras.metrics.AUC(name='AUC'),
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')],
)
history = stacked_model.fit(train_generator_func(train_generator),
                                steps_per_epoch=len(train_generator), 
                                validation_data=val_generator_func(validation_generator),
                                validation_steps = len(validation_generator),
                                epochs=25,
                                verbose = 1,
                                initial_epoch=history.epoch[-1],
                                class_weight = class_weights,
                                callbacks=[reducelr, earlystop,checkpoint,lambdacb])
# Out:
# Beginning training
# Learning rate:  1e-05
# Epoch 15/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9913 - AUC: 0.9994 - precision: 0.9920 - recall: 0.9909
# Epoch 00015: val_loss did not improve from 0.08606
# End of epoch 14. Learning rate: 1e-05
# 571/571 [==============================] - 156s 254ms/step - loss: 0.0278 - accuracy: 0.9913 - AUC: 0.9994 - precision: 0.9920 - recall: 0.9909 - val_loss: 0.0999 - val_accuracy: 0.9759 - val_AUC: 0.9943 - val_precision: 0.9759 - val_recall: 0.9759 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9903 - AUC: 0.9992 - precision: 0.9907 - recall: 0.9900
# Epoch 00016: val_loss did not improve from 0.08606
# End of epoch 15. Learning rate: 1e-05
# 571/571 [==============================] - 139s 243ms/step - loss: 0.0313 - accuracy: 0.9903 - AUC: 0.9992 - precision: 0.9907 - recall: 0.9900 - val_loss: 0.0990 - val_accuracy: 0.9759 - val_AUC: 0.9945 - val_precision: 0.9768 - val_recall: 0.9754 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9906 - AUC: 0.9991 - precision: 0.9914 - recall: 0.9904
# Epoch 00017: val_loss did not improve from 0.08606
# End of epoch 16. Learning rate: 1e-05
# 571/571 [==============================] - 137s 241ms/step - loss: 0.0308 - accuracy: 0.9906 - AUC: 0.9991 - precision: 0.9914 - recall: 0.9904 - val_loss: 0.0995 - val_accuracy: 0.9754 - val_AUC: 0.9952 - val_precision: 0.9754 - val_recall: 0.9754 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9898 - AUC: 0.9991 - precision: 0.9903 - recall: 0.9888
# Epoch 00018: val_loss did not improve from 0.08606
# End of epoch 17. Learning rate: 1e-05
# 571/571 [==============================] - 149s 261ms/step - loss: 0.0322 - accuracy: 0.9898 - AUC: 0.9991 - precision: 0.9903 - recall: 0.9888 - val_loss: 0.1014 - val_accuracy: 0.9769 - val_AUC: 0.9939 - val_precision: 0.9769 - val_recall: 0.9769 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9921 - AUC: 0.9991 - precision: 0.9922 - recall: 0.9913
# Epoch 00019: val_loss did not improve from 0.08606
# End of epoch 18. Learning rate: 1e-05
# 571/571 [==============================] - 151s 265ms/step - loss: 0.0292 - accuracy: 0.9921 - AUC: 0.9991 - precision: 0.9922 - recall: 0.9913 - val_loss: 0.1003 - val_accuracy: 0.9759 - val_AUC: 0.9941 - val_precision: 0.9759 - val_recall: 0.9759 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9906 - AUC: 0.9996 - precision: 0.9914 - recall: 0.9905
# Epoch 00020: val_loss did not improve from 0.08606
# End of epoch 19. Learning rate: 1e-05
# 571/571 [==============================] - 136s 239ms/step - loss: 0.0275 - accuracy: 0.9906 - AUC: 0.9996 - precision: 0.9914 - recall: 0.9905 - val_loss: 0.0993 - val_accuracy: 0.9764 - val_AUC: 0.9941 - val_precision: 0.9764 - val_recall: 0.9764 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 21/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9912 - AUC: 0.9995 - precision: 0.9921 - recall: 0.9908
# Epoch 00021: val_loss did not improve from 0.08606
# End of epoch 20. Learning rate: 1e-05
# 571/571 [==============================] - 136s 238ms/step - loss: 0.0253 - accuracy: 0.9912 - AUC: 0.9995 - precision: 0.9921 - recall: 0.9908 - val_loss: 0.0996 - val_accuracy: 0.9764 - val_AUC: 0.9942 - val_precision: 0.9764 - val_recall: 0.9759 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 22/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9897 - AUC: 0.9990 - precision: 0.9901 - recall: 0.9893
# Epoch 00022: val_loss did not improve from 0.08606
# End of epoch 21. Learning rate: 1e-05
# 571/571 [==============================] - 142s 250ms/step - loss: 0.0332 - accuracy: 0.9897 - AUC: 0.9990 - precision: 0.9901 - recall: 0.9893 - val_loss: 0.0981 - val_accuracy: 0.9744 - val_AUC: 0.9956 - val_precision: 0.9744 - val_recall: 0.9744 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 23/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9921 - AUC: 0.9992 - precision: 0.9923 - recall: 0.9920
# Epoch 00023: val_loss did not improve from 0.08606
# End of epoch 22. Learning rate: 1e-05
# 571/571 [==============================] - 143s 251ms/step - loss: 0.0284 - accuracy: 0.9921 - AUC: 0.9992 - precision: 0.9923 - recall: 0.9920 - val_loss: 0.1000 - val_accuracy: 0.9764 - val_AUC: 0.9942 - val_precision: 0.9764 - val_recall: 0.9764 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 24/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9919 - AUC: 0.9995 - precision: 0.9921 - recall: 0.9915
# Epoch 00024: val_loss did not improve from 0.08606
# End of epoch 23. Learning rate: 1e-05
# 571/571 [==============================] - 141s 247ms/step - loss: 0.0244 - accuracy: 0.9919 - AUC: 0.9995 - precision: 0.9921 - recall: 0.9915 - val_loss: 0.0983 - val_accuracy: 0.9749 - val_AUC: 0.9953 - val_precision: 0.9749 - val_recall: 0.9749 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 25/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9911 - AUC: 0.9990 - precision: 0.9915 - recall: 0.9907
# Epoch 00025: val_loss did not improve from 0.08606
# End of epoch 24. Learning rate: 1e-05
# 571/571 [==============================] - 144s 252ms/step - loss: 0.0304 - accuracy: 0.9911 - AUC: 0.9990 - precision: 0.9915 - recall: 0.9907 - val_loss: 0.0985 - val_accuracy: 0.9764 - val_AUC: 0.9945 - val_precision: 0.9768 - val_recall: 0.9759 - lr: 1.0000e-05

# %% [markdown]
# ### Stacked Generalization Evaluation

# %%
TEST_IMAGE_FOLDER = '/home/TBX11K/BF/test/Shenzhen'
test_generator = test_datagen.flow_from_directory(
        TEST_IMAGE_FOLDER,
        target_size=TARGET_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=False,
        class_mode=CLASS_MODE)
filenames = test_generator.filenames
test_gen = val_generator_func(test_generator)
# Out:
# Found 331 images belonging to 3 classes.

# %%
sg_ensemble = tf.keras.models.load_model('./weights/sg_bf5.hdf5')
predict = sg_ensemble.predict(test_gen,steps = len(filenames)/BATCH_SIZE)

# %%
from sklearn.metrics import classification_report
predicted = np.argmax(predict, axis=1)
report = classification_report(test_generator.classes, predicted)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82       163
#            1       0.00      0.00      0.00         0
#            2       0.80      0.93      0.86       168
#
#     accuracy                           0.84       331
#    macro avg       0.57      0.56      0.56       331
# weighted avg       0.85      0.84      0.84       331

# %% [markdown]
# #### Montgomery Dataset Evaluation

# %%
TEST_IMAGE_FOLDER = '/home/TBX11K/BF/test/Montgomery'
test_generator = test_datagen.flow_from_directory(
        TEST_IMAGE_FOLDER,
        target_size=TARGET_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=False,
        class_mode=CLASS_MODE)
filenames = test_generator.filenames
test_gen = val_generator_func(test_generator)
predict = sg_ensemble.predict(test_gen,steps = len(filenames)/BATCH_SIZE)
# Out:
# Found 69 images belonging to 3 classes.

# %%
from sklearn.metrics import classification_report
predicted = np.argmax(predict, axis=1)
report = classification_report(test_generator.classes, predicted)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87        40
#            2       0.91      0.69      0.78        29
#
#     accuracy                           0.84        69
#    macro avg       0.86      0.82      0.83        69
# weighted avg       0.85      0.84      0.84        69
